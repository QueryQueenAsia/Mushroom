# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('mushroom_decoded.csv')
data.head(7)
# Out:
#        class cap-shape cap-surface cap-color bruises?     odor  \
# 0     edible    convex      smooth         y        t   almond
# 1     edible      bell      smooth         w        t    anise
# 2  poisonous    convex       scaly         w        t  pungent
# 3     edible    convex      smooth         g        f     none
# 4     edible    convex       scaly         y        t   almond
# 5     edible      bell      smooth         w        t   almond
# 6     edible      bell       scaly         w        t    anise
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0               f            c         b          k  ...
# 1               f            c         b          n  ...
# 2               f            c         n          n  ...
# 3               f            w         b          k  ...
# 4               f            c         b          n  ...
# 5               f            c         b          g  ...
# 6               f            c         b          n  ...
# ...

# %%
from pickle import DICT
